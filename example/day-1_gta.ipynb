# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("gta_v_worldwide_sales_player_analytics_2013_2026.csv")

df.head()
# Out:
#   transaction_id  year  month  quarter    country iso3_code         region  \
# 0    GTA5-100039  2013      9        3    Algeria       DZA         Africa
# 1    GTA5-100005  2013      9        3  Argentina       ARG  South America
# 2    GTA5-100093  2013      9        3  Argentina       ARG  South America
# 3    GTA5-100072  2013      9        3    Armenia       ARM           Asia
# 4    GTA5-100034  2013      9        3  Australia       AUS        Oceania
#
#    platform      game_edition sales_channel  ... gaming_market_size  \
# 0       PS3   Premium Edition      Physical  ...               4.82
# 1       PS3  Standard Edition      Physical  ...              23.48
# 2  Xbox 360   Premium Edition      Physical  ...              23.96
# 3       PS3  Standard Edition      Physical  ...               0.14
# 4       PS3    Legacy Edition      Physical  ...             231.44
#
#    population_millions  gdp_per_capita_usd  release_phase  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14780 entries, 0 to 14779
# Data columns (total 47 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   transaction_id                   14780 non-null  object
#  1   year                             14780 non-null  int64
#  2   month                            14780 non-null  int64
#  3   quarter                          14780 non-null  int64
#  4   country                          14780 non-null  object
#  5   iso3_code                        14780 non-null  object
#  6   region                           14780 non-null  object
#  7   platform                         14780 non-null  object
#  8   game_edition                     14780 non-null  object
#  9   sales_channel                    14780 non-null  object
#  10  retailer                         14780 non-null  object
#  11  units_sold                       14780 non-null  int64
# ...

# %%
df.describe(include="all")
# Out:
#        transaction_id          year         month       quarter    country  \
# count           14780  14780.000000  14780.000000  14780.000000      14780
# unique          14780           NaN           NaN           NaN         88
# top       GTA5-114713           NaN           NaN           NaN  Argentina
# freq                1           NaN           NaN           NaN        269
# mean              NaN   2019.580920      6.525440      2.500406        NaN
# std               NaN      3.724658      3.480096      1.122421        NaN
# min               NaN   2013.000000      1.000000      1.000000        NaN
# 25%               NaN   2016.000000      3.000000      1.000000        NaN
# 50%               NaN   2020.000000      6.000000      2.000000        NaN
# 75%               NaN   2023.000000     10.000000      4.000000        NaN
# max               NaN   2026.000000     12.000000      4.000000        NaN
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["units_sold"], bins=20)

plt.title("Histogram of Units Sold")
plt.xlabel("Units Sold")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['customer_rating'], bins=15)

plt.title("Customer Rating Distribution")
plt.xlabel("Customer Rating")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.boxplot(df['customer_rating'])

plt.title("Box Plot of Customer Rating")
plt.ylabel("Customer Rating")

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['average_playtime_hours'])

plt.title("Box Plot of Average Playtime")
plt.ylabel("Hours")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("gta_v_worldwide_sales_player_analytics_2013_2026.csv")

plt.figure(figsize=(8,5))
sns.boxplot(y=df["average_playtime_hours"])

plt.title("Box Plot of Hours")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("gta_v_worldwide_sales_player_analytics_2013_2026.csv")

plt.figure(figsize=(8,5))
sns.boxplot(y=df["customer_rating"])

plt.title("Box Plot of Customer Rating")
plt.show()

# %% [markdown]
# correlation matrix

# %%
numeric_df = df.select_dtypes(include=['number'])

corr = numeric_df.corr()

print(corr)
# Out:
#                                      year     month   quarter  units_sold  \
# year                             1.000000 -0.110705 -0.110681    0.086215
# month                           -0.110705  1.000000  0.972027    0.085034
# quarter                         -0.110681  0.972027  1.000000    0.072728
# units_sold                       0.086215  0.085034  0.072728    1.000000
# gross_revenue_usd               -0.183301  0.063607  0.064606    0.850264
# average_selling_price_usd       -0.649319 -0.082958 -0.030153   -0.186618
# discount_percentage             -0.005034  0.160912  0.071841    0.209865
# digital_sales_percentage         0.814823 -0.036797 -0.039185    0.112118
# physical_sales_percentage       -0.814823  0.036797  0.039185   -0.112118
# new_customers                   -0.142985  0.091037  0.079633    0.933967
# returning_customers              0.236922  0.074468  0.062476    0.969480
# estimated_active_players         0.139150  0.009115  0.006717    0.867172
# ...

# %% [markdown]
#  Correlation Value (r) | Interpretation
#  --------------------: | --------------------------------
#               **+1.0** | Perfect Positive Correlation
#      **+0.8 to +0.99** | Very Strong Positive Correlation
#      **+0.6 to +0.79** | Strong Positive Correlation
#      **+0.4 to +0.59** | Moderate Positive Correlation
#      **+0.2 to +0.39** | Weak Positive Correlation
#                  **0** | No Correlation
#      **−0.2 to −0.39** | Weak Negative Correlation
#      **−0.4 to −0.59** | Moderate Negative Correlation
#      **−0.6 to −0.79** | Strong Negative Correlation
#      **−0.8 to −0.99** | Very Strong Negative Correlation
#               **−1.0** | Perfect Negative Correlation

# %% [markdown]
# correlation Matrix with heat map

# %%
numeric_df = df.select_dtypes(include=['number'])

corr = numeric_df.corr()

plt.figure(figsize=(18,14))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")

plt.title("Correlation Matrix with heatmap")
plt.show()

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(df[['units_sold',
                 'year',]])

plt.show()

# %%
sns.pairplot(df[['units_sold',
                 'year',
                 'customer_rating']])

plt.show()

# %%
import pandas as pd

dff = pd.read_csv("gtacopyds.csv")

dff.head()
# Out:
#   transaction_id  year  month  quarter    country iso3_code         region  \
# 0    GTA5-100039  2013      9        3    Algeria       DZA         Africa
# 1    GTA5-100005  2013      9        3  Argentina       ARG  South America
# 2    GTA5-100093  2013      9        3  Argentina       ARG  South America
# 3    GTA5-100072  2013      9        3    Armenia       ARM           Asia
# 4    GTA5-100034  2013      9        3  Australia       AUS        Oceania
#
#    platform      game_edition sales_channel  ... gaming_market_size  \
# 0       PS3   Premium Edition      Physical  ...               4.82
# 1       PS3  Standard Edition      Physical  ...              23.48
# 2  Xbox 360   Premium Edition      Physical  ...              23.96
# 3       PS3  Standard Edition      Physical  ...               0.14
# 4       PS3    Legacy Edition      Physical  ...             231.44
#
#    population_millions gdp_per_capita_usd  release_phase  \
# ...

# %% [markdown]
# missing values find

# %%
dff.isnull().sum()
# Out:
# transaction_id                        0
# year                                  0
# month                                 0
# quarter                               0
# country                               0
# iso3_code                             0
# region                                1
# platform                              0
# game_edition                          2
# sales_channel                         0
# retailer                              1
# units_sold                            0
# gross_revenue_usd                     2
# average_selling_price_usd             0
# discount_percentage                   2
# digital_sales_percentage              1
# physical_sales_percentage             1
# new_customers                         3
# returning_customers                   0
# estimated_active_players              8
# peak_concurrent_players               3
# online_players                        0
# story_mode_players                    1
# ...

# %%
import pandas as pd

df = pd.read_csv("gta_v_worldwide_sales_player_analytics_2013_2026.csv")

df.isnull().sum()
# Out:
# transaction_id                        0
# year                                  0
# month                                 0
# quarter                               0
# country                               0
# iso3_code                             0
# region                                0
# platform                              0
# game_edition                          0
# sales_channel                         0
# retailer                              0
# units_sold                            0
# gross_revenue_usd                     0
# average_selling_price_usd             0
# discount_percentage                   0
# digital_sales_percentage              0
# physical_sales_percentage             0
# new_customers                         0
# returning_customers                   0
# estimated_active_players              0
# peak_concurrent_players               0
# online_players                        0
# story_mode_players                    0
# ...

# %%
df = df[()]
